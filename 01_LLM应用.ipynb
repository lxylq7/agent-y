# %%
#sk-e43e9e71e7d748f8bad25bd6ccc8e68c

# %%
from langchain_community.llms import tongyi
key = "sk-e43e9e71e7d748f8bad25bd6ccc8e68c"
llm = tongyi.Tongyi(api_key=key)
#调用模型使用
info = llm.invoke("夏天适合吃什么水果?了")
print(info)
# Out:
# 夏天天气炎热、湿度大，人体容易出汗多、食欲下降、易上火或脾胃虚弱，因此适合选择**清热解暑、生津止渴、富含水分和维生素、性质偏凉或平和**的水果。以下是一些非常适合夏季食用的水果及简要建议：
#
# ✅ **推荐水果（兼顾营养与时令性）：**
# 1. **西瓜** 🍉
# 　- 含水量高达90%以上，清热解暑、利尿消肿；
# 　- 适量食用（尤其避免冰镇过久或空腹大量吃），脾胃虚寒、糖尿病患者需控制量。
#
# 2. **哈密瓜 / 蜜瓜** 🍈
# 　- 富含β-胡萝卜素、钾和维生素C，润燥生津、助消化；
# 　- 性微凉，香甜不腻，比西瓜更温和，适合多数体质。
#
# 3. **桃子** 🍑（尤其是水蜜桃）
# 　- 补益气血、生津润肠，含丰富果胶和有机酸，助开胃；
# 　- 建议选成熟度适中的，避免未熟桃子引发腹胀。
#
# 4. **李子 / 杨梅** 🍒
# 　- 酸甘化阴，生津止渴、促进消化；杨梅富含花青素，抗氧化强；
# 　- 注意清洗干净（杨梅易藏虫卵），肠胃敏感者不宜空腹多食。
#
# 5. **荔枝 / 龙眼（适量！）** 🍇
# 　- 夏季时令，补益心脾、养血安神；但性温易上火，⚠️切忌过量（尤其儿童，有“荔枝病”风险）；
# 　　✅建议：成人每日≤10颗荔枝，饭后食用，搭配绿豆汤/冬瓜水平衡。
#
# 6. **梨（如翠冠梨、雪梨）** 🍐
# 　- 清热润肺、生津止渴，夏季燥热或空调房待久易口干咽燥，梨是良伴；
# 　- 可生吃、蒸梨（加川贝/冰糖缓解咳嗽）、或煮梨水。
#
# 7. **葡萄（尤其巨峰、夏黑）** 🍇
# 　- 富含葡萄糖、有机酸、多酚类物质，提神解乏、抗氧化；
# 　- 性平微凉，洗净后连皮吃（花青素主要在皮中）。
#
# 8. **芒果（熟透者）** 🥭
# 　- 维生素A、C丰富，润肤明目；但属“发物”，过敏体质、湿疹或咽喉肿痛者慎食；
# 　　✅小贴士：削皮后用盐水泡几分钟可减少致敏蛋白。
#
# 🌿 **加分小知识：**
# - ✅ 搭配建议：水果可搭配薄荷叶、柠檬片、少量蜂蜜（糖尿病者免）做清爽果饮；
# - ❌ 避免：长期大量吃冰镇水果（伤脾胃阳气）、空腹吃高酸水果（如未熟李子、山楂）刺激胃；
# - 🌟 中医提醒：“春夏养阳”，即使吃凉性水果，也建议常温食用，体寒者可搭配姜茶或陈皮水调和。
#
# ...

# %%
#智普ai
key = 'b96d974eb5eb4648b9cdc76fbf423ddd.1bg7tnqu3cyIlpVg'

from langchain_community.chat_models import ChatZhipuAI
from langchain_core.messages import AIMessage, HumanMessage, SystemMessage
import os
os.environ["ZHIPUAI_API_KEY"] = key
chat = ChatZhipuAI(
    model="glm-4",
    temperature=0.5, #模型温度  值在0-1之间 值越小 随机性越低
)
messages = [
    SystemMessage(content="你是一个助手,请用中文回复"),
    HumanMessage(content="请写一首关于春天的诗"),
]
response = chat.invoke(messages)
print(response.content)  # Displays the AI-generated poem
# Out:
# c:\Users\lv\.conda\envs\agent-env\Lib\site-packages\jwt\api_jwt.py:147: InsecureKeyLengthWarning: The HMAC key is 16 bytes long, which is below the minimum recommended length of 32 bytes for SHA256. See RFC 7518 Section 3.2.
#   return self._jws.encode(
# 《春之韵》
#
# 东风轻拂柳丝长，
# 桃花含笑映春光。
# 细雨润物无声处，
# 万物复苏满园香。
#
# 燕子归来筑新巢，
# 溪水潺潺绕山梁。
# 儿童嬉戏芳草绿，
# 风筝高飞入云霄。
#
# 春意盎然心欢畅，
# 岁月如诗韵悠长。
# 愿此美景常相伴，
# 人间四月好时光。

# %%
from langchain_ollama import ChatOllama
from langchain_core.messages import HumanMessage

model = ChatOllama(model="deepseek-r1:1.5b")
response = model.invoke([HumanMessage(content="夏天吃什么水果？")])
print(response.content)
# Out:
# 在夏季，为了保持清爽和健康，可以选择以下水果来搭配：
#
# 1. **西瓜**：酸甜适中，富含水分和维生素C。
# 2. **蓝莓**：清新脱皮，富含抗氧化剂。
# 3. **草莓**：含有丰富的维生素C和膳食纤维。
# 4. **哈密瓜**：含有丰富的维生素A和纤维，有助于促进消化。
# 5. **西瓜**：常用于制作蛋糕、沙拉和甜点。
# 6. **苹果**：酸爽但易储存，适合夏季消暑。
# 7. **葡萄**：富含维生素C和膳食纤维，适合脱皮皮肤。
# 8. **柠檬汁**：酸味清新，帮助提升整体清爽感。
#
# 此外，新鲜的蔬果如：
# - **橙子**：带有一丝苦涩的味道，口感甘甜。
# - **番茄**：含有丰富的维生素C和抗氧化剂。
# - **梨子**：酸甜可口，适合搭配水果沙拉。
#
# 这些水果不仅美味，还能增强体质，所以夏天可以适当吃一些。
